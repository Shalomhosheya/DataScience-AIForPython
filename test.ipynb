# %%
# a = 200
# print("The type of variable having value",a,"is",type(a))
# print()
# b = 112.5487

# print("The type of variable having value",b,"is",type(b))
# print()
# num_1=2.5e4

# print("The type of variable having value",num_1,"is",type(num_1))
# print() 
# num_3=5
# num_4=12.7
# a=float(num_3)

# print(a)
# print()

# b=int(num_4)

# print(b,type(b))
# print()
# my_list=[1,10,15,8]

# print(my_list,type(my_list))
# print()

# print(my_list[1],type(my_list[1]))
# print()
# my_list[1]=25

# print(my_list[1],type(my_list[1]))
# print()

# my_list[2]="cat"

# print(my_list[2],type(my_list[2]))

# print()

# print(my_list)
# print()

# list3=[10,10,1,"cat",8,True]
# print()

# print(list3[3],type(list3[3]))
# print(list3[-2])
# print()

# print(list3[1:4]) #to abstract three data syntax must be increment
# print()

# print(list3[:3])
# print()

# print(list3[3:])

# list3[2:4]=[19.0,"dog"]

# print(list3)

# list3.insert(3,"rabbit")#add specific index to list
# print()

# print(list3,type(list3))
# print()

# list3.append("car")#add to last in the list 
# print(list3)
# print()

# new_list=[10,20,"bruh"]

# list3.extend(new_list)#extend the list with another list

# print(list3)
# print()

# list3.pop(2)#removes the element passed in the bracket
# print(list3)
# print()

# del list3[4]#removes the element passed in the bracket
# print(list3)
# print()

# # del list3 #clears the whole list
# # print(list3)

# list3.clear()
# print(list3,len(list3))
# print()

# list4=["dog","apple","orange","lion","Parrot"]
# list4.sort()#sorting is done in this list but this is case sensitivity
# print(list4)
# print()

# list4.sort(key=str.lower)#sorting is done in this list , this is case Insensitivity
# print(list4)
# print()

# list4.sort(reverse=True)#reverse the whole list data as decesending order
# print(list4)
# print()


list5=[-10,-18,12,5,7,12,-3]
list6=[8,4,-3,9,2,11]


print(list5)
print(list6)


list5.extend(list6)
list5.sort()
print(list5)

c=len(list5)
c/=2
d=int(c)
print(d)

print("median value: ",list5[d])

c=len(list5)
c/=4
d=int(c)
print(d)

print("Q1 value:",list5[d])

c=len(list5)
c/=4
d=int(c)
d*3
print(d)

print("Q3 value:",list5[d])#9
# Out:
# [-10, -18, 12, 5, 7, 12, -3]
# [8, 4, -3, 9, 2, 11]
# [-18, -10, -3, -3, 2, 4, 5, 7, 8, 9, 11, 12, 12]
# 6
# median value:  5
# 3
# Q1 value: -3
# 3
# Q3 value: -3
